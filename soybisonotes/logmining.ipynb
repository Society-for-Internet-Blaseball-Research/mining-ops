# %%
import numpy as np
import pandas as pd
import json
import glob

# %%
files = glob.glob('./ilianas_records/s3/*')
files[1]
# Out:
# './ilianas_records/s3/blaseball-log-1596533432516.json'

# %%
raw = []
for log in files:
    with open(log, 'r') as f:
        for bleep in f.readlines():
            raw.append(json.loads(bleep))

# %%
for obj in raw:
    schedge = obj['schedule']
    for sked in schedge:
# Out:
# [{'basesOccupied': [],
#   'baseRunners': [],
#   'outcomes': [],
#   '_id': 'd8f95c60-a1c6-40f6-9d9f-25511a0f2c68',
#   'terminology': 'b67e9bbb-1495-4e1b-b517-f1444b0a6c8b',
#   'lastUpdate': 'Stu Trololol batting for the Shoe Thieves.',
#   'rules': '4ae9d46a-5408-460a-84fb-cbd8d03fff6c',
#   'statsheet': 'f69a6db4-544a-4d26-ba1e-13fd98c7249a',
#   'awayPitcher': '36786f44-9066-4028-98d9-4fa84465ab9e',
#   'awayPitcherName': 'Beasley Gloom',
#   'awayBatter': 'd47dd08e-833c-4302-a965-a391d345455c',
#   'awayBatterName': 'Stu Trololol',
#   'awayTeam': 'bfd38797-8404-4b38-8b82-341da28b1f83',
#   'awayTeamName': 'Charleston Shoe Thieves',
#   'awayTeamNickname': 'Shoe Thieves',
#   'awayTeamColor': '#ffce0a',
#   'awayTeamEmoji': '0x1F45F',
#   'awayOdds': 0.5413947119936758,
#   'awayStrikes': 3,
#   'awayScore': 4,
#   'awayTeamBatterCount': 22,
#   'homePitcher': '740d5fef-d59f-4dac-9a75-739ec07f91cf',
#   'homePitcherName': 'Conner Haley',
#   'homeBatter': '',
# ...

# %%
raw[3]['schedule']
# Out:
# [{'basesOccupied': [],
#   'baseRunners': [],
#   'outcomes': [],
#   '_id': '6afe8293-ee97-4b75-b75c-444fce3da0b0',
#   'terminology': 'b67e9bbb-1495-4e1b-b517-f1444b0a6c8b',
#   'lastUpdate': 'Game over.',
#   'rules': '4ae9d46a-5408-460a-84fb-cbd8d03fff6c',
#   'statsheet': '5f958c2a-7b0f-4289-adbb-2f55ec64e6e2',
#   'awayPitcher': '9786b2c9-1205-4718-b0f7-fc000ce91106',
#   'awayPitcherName': 'Kevin Dudley',
#   'awayBatter': '',
#   'awayBatterName': '',
#   'awayTeam': '23e4cbc1-e9cd-47fa-a35b-bfa06f726cb7',
#   'awayTeamName': 'Philly Pies',
#   'awayTeamNickname': 'Pies',
#   'awayTeamColor': '#399d8f',
#   'awayTeamEmoji': '0x1F967',
#   'awayOdds': 0.4544000813179283,
#   'awayStrikes': 3,
#   'awayScore': 7,
#   'awayTeamBatterCount': 34,
#   'homePitcher': 'e6502bc7-5b76-4939-9fb8-132057390b30',
#   'homePitcherName': 'Greer Lott',
#   'homeBatter': '',
#   'homeBatterName': '',
#   'homeTeam': 'eb67ae5e-c4bf-46ca-bbbc-425cd34182ff',
# ...
